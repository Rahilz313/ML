# %%
# 1st way of writing 
from matplotlib import pyplot as plt
#or  2nd way of writing 
import matplotlib.pyplot as plt
import matplotlib as mlt
import numpy as np
import pandas as pan

# %%
## Data preprocessing (cleaning the Data) using the pandas 
#options
# 1. drop the data
# 2.Replace the data

# %%
titanic=pan.read_csv("C:\\Users\\admin\\Downloads\\titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# to know how many null values are there in a column
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# this function is used to know how many not null values are there
titanic.notna().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
# this function will drop null value rows
t=titanic.dropna()

# %%
t
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t.shape
# Out:
# (183, 12)

# %%
t.notna()
# Out:
#      PassengerId  Survived  Pclass  Name   Sex   Age  SibSp  Parch  Ticket  \
# 1           True      True    True  True  True  True   True   True    True
# 3           True      True    True  True  True  True   True   True    True
# 6           True      True    True  True  True  True   True   True    True
# 10          True      True    True  True  True  True   True   True    True
# 11          True      True    True  True  True  True   True   True    True
# ..           ...       ...     ...   ...   ...   ...    ...    ...     ...
# 871         True      True    True  True  True  True   True   True    True
# 872         True      True    True  True  True  True   True   True    True
# 879         True      True    True  True  True  True   True   True    True
# 887         True      True    True  True  True  True   True   True    True
# 889         True      True    True  True  True  True   True   True    True
#
#      Fare  Cabin  Embarked
# 1    True   True      True
# ...

# %%
# this function will fill all the value with the given value
titanic.fillna('abcd')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['Cabin'].fillna('abcd').shape
# Out:
# (891,)

# %%
t=titanic.dropna(subset=['Embarked'])

# %%
t.shape
# Out:
# (889, 12)

# %%
t1=titanic.dropna(subset=['Age','Embarked'])

# %%
t1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t1.shape
# Out:
# (712, 12)

# %%
t3=titanic.dropna(how='all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1092\3315186926.py in <module>
# ----> 1 t3=titanic.dropna(how='all')
#
# NameError: name 'titanic' is not defined

# %%
t3.shape
# Out:
# (891, 12)

# %%
t3=titanic.dropna(how='any')

# %%
t3
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t3.shape
# Out:
# (183, 12)

# %%
t5=titanic.drop_duplicates()

# %%
t5.shape
# Out:
# (891, 12)

# %%
titanic.loc[888,'Age']=22

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.loc[888,'Age']=None

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
f=titanic['Age'].mean() # calculating mean value of age column

# %%
f
# Out:
# 29.69911764705882

# %%
titanic['Age'].fillna(f,inplace=True) # filling the mean value inplace  of null value in Age column

# %%
titanic.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic['Survived']=titanic['Survived'].replace([0],'No')

# %%
titanic
# Out:
#      PassengerId Survived  Pclass  \
# 0              1       No       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5       No       3
# ..           ...      ...     ...
# 886          887       No       2
# 887          888        1       1
# 888          889       No       3
# 889          890        1       1
# 890          891       No       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
titanic['Survived']=titanic['Survived'].replace([1],'Yes')

# %%
titanic
# Out:
#      PassengerId Survived  Pclass  \
# 0              1       No       3
# 1              2      Yes       1
# 2              3      Yes       3
# 3              4      Yes       1
# 4              5       No       3
# ..           ...      ...     ...
# 886          887       No       2
# 887          888      Yes       1
# 888          889       No       3
# 889          890      Yes       1
# 890          891       No       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
titanic['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
# here we are replacing the values 

titanic['Embarked'].replace({'C':'Cherbourg','Q':'Queenstown','S':'Southhampton'},inplace=True)

# another way titanic['Embarked'].replace(['C','Q','S'],['Cherbourg','Queenstown','Southhampton'],inplace=True

# %%
titanic
# Out:
#      PassengerId Survived  Pclass  \
# 0              1       No       3
# 1              2      Yes       1
# 2              3      Yes       3
# 3              4      Yes       1
# 4              5       No       3
# ..           ...      ...     ...
# 886          887       No       2
# 887          888      Yes       1
# 888          889       No       3
# 889          890      Yes       1
# 890          891       No       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
titanic
# Out:
#      PassengerId Survived  Pclass  \
# 0              1       No       3
# 1              2      Yes       1
# 2              3      Yes       3
# 3              4      Yes       1
# 4              5       No       3
# ..           ...      ...     ...
# 886          887       No       2
# 887          888      Yes       1
# 888          889       No       3
# 889          890      Yes       1
# 890          891       No       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
titanic['Embarked'].replace()
# Out:
# 0      Southhampton
# 1         Cherbourg
# 2      Southhampton
# 3      Southhampton
# 4      Southhampton
#            ...
# 886    Southhampton
# 887    Southhampton
# 888    Southhampton
# 889       Cherbourg
# 890      Queenstown
# Name: Embarked, Length: 891, dtype: object

# %%
titanic['Swimming']=None

# %%
titanic
# Out:
#      PassengerId Survived  Pclass  \
# 0              1       No       3
# 1              2      Yes       1
# 2              3      Yes       3
# 3              4      Yes       1
# 4              5       No       3
# ..           ...      ...     ...
# 886          887       No       2
# 887          888      Yes       1
# 888          889       No       3
# 889          890      Yes       1
# 890          891       No       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
titanic1=titanic.copy()

# %%
# giving random values to a column
titanic['Swimming']=random.choices(['Yes','No'], k=len(titanic))

# %%
titanic
# Out:
#           PassengerId Survived  Pclass  \
# 0                 1.0       No     3.0
# 1                 2.0      Yes     1.0
# 2                 3.0      Yes     3.0
# 3                 4.0      Yes     1.0
# 4                 5.0       No     3.0
# ...               ...      ...     ...
# 887             888.0      Yes     1.0
# 888             889.0       No     3.0
# 889             890.0      Yes     1.0
# 890             891.0       No     3.0
# Swimming          NaN      NaN     NaN
#
#                                                        Name     Sex  \
# 0                                   Braund, Mr. Owen Harris    male
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                    Heikkinen, Miss. Laina  female
# 3              Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                                  Allen, Mr. William Henry    male
# ...                                                     ...     ...
# ...

# %%
# comdition based on differeent table
titanic.loc[titanic["Survived"]=='Yes', "Swimming"] = 1

# %%
titanic.loc[titanic['Survived']=='No','Swimming']=0

# %%
titanic
# Out:
#           PassengerId Survived  Pclass  \
# 0                 1.0       No     3.0
# 1                 2.0      Yes     1.0
# 2                 3.0      Yes     3.0
# 3                 4.0      Yes     1.0
# 4                 5.0       No     3.0
# ...               ...      ...     ...
# 887             888.0      Yes     1.0
# 888             889.0       No     3.0
# 889             890.0      Yes     1.0
# 890             891.0       No     3.0
# Swimming          NaN      NaN     NaN
#
#                                                        Name     Sex  \
# 0                                   Braund, Mr. Owen Harris    male
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                    Heikkinen, Miss. Laina  female
# 3              Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                                  Allen, Mr. William Henry    male
# ...                                                     ...     ...
# ...

# %%
titanic.drop('Swimming',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8784\1506532523.py in <module>
# ----> 1 titanic.drop('Swimming',axis=1,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
titanic
# Out:
#           PassengerId Survived  Pclass  \
# 0                 1.0       No     3.0
# 1                 2.0      Yes     1.0
# 2                 3.0      Yes     3.0
# 3                 4.0      Yes     1.0
# 4                 5.0       No     3.0
# ...               ...      ...     ...
# 887             888.0      Yes     1.0
# 888             889.0       No     3.0
# 889             890.0      Yes     1.0
# 890             891.0       No     3.0
# Swimming          NaN      NaN     NaN
#
#                                                        Name     Sex  \
# 0                                   Braund, Mr. Owen Harris    male
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                    Heikkinen, Miss. Laina  female
# 3              Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                                  Allen, Mr. William Henry    male
# ...                                                     ...     ...
# ...

# %%
titanic
# Out:
#           PassengerId Survived  Pclass  \
# 0                 1.0       No     3.0
# 1                 2.0      Yes     1.0
# 2                 3.0      Yes     3.0
# 3                 4.0      Yes     1.0
# 4                 5.0       No     3.0
# ...               ...      ...     ...
# 887             888.0      Yes     1.0
# 888             889.0       No     3.0
# 889             890.0      Yes     1.0
# 890             891.0       No     3.0
# Swimming          NaN      NaN     NaN
#
#                                                        Name     Sex  \
# 0                                   Braund, Mr. Owen Harris    male
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                    Heikkinen, Miss. Laina  female
# 3              Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                                  Allen, Mr. William Henry    male
# ...                                                     ...     ...
# ...

# %%
titanic.drop('Swimming',axis=0,inplace=True)

# %%
titanic
# Out:
#      PassengerId Survived  Pclass  \
# 0            1.0       No     3.0
# 1            2.0      Yes     1.0
# 2            3.0      Yes     3.0
# 3            4.0      Yes     1.0
# 4            5.0       No     3.0
# ..           ...      ...     ...
# 886        887.0       No     2.0
# 887        888.0      Yes     1.0
# 888        889.0       No     3.0
# 889        890.0      Yes     1.0
# 890        891.0       No     3.0
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...
